# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output

txt_path = "instances/C266.TXT"
file = open(txt_path, 'r')
import re
number = 0
capacity = 0
counter = 0
customers = pd.DataFrame(columns = ['CUST NO', 'XCOORD', 'YCOORD', 'DEMAND', 'READY TIME', 'DUE DATE', 'SERVICE TIME', 'VISITED'])
for line in file:
    if (counter == 4):
        values = re.findall("\s*\d*\s*", line)
        number = int(values[0].replace(" ", ""))
        capacity = int(values[1].replace(" ", ""))
    if (counter > 8):
        values = re.findall("\s*\d*\s*", line)
        customers = customers.append({'CUST NO' : int(values[0].replace(" ", "")), 
                          'XCOORD' : int(values[1].replace(" ", "")), 
                          'YCOORD' : int(values[2].replace(" ", "")), 
                          'DEMAND' : int(values[3].replace(" ", "")), 
                          'READY TIME' : int(values[4].replace(" ", "")), 
                          'DUE DATE' : int(values[5].replace(" ", "")), 
                          'SERVICE TIME' : int(values[6].replace(" ", "")),
                          'VISITED': False}, ignore_index=True)
    counter = counter + 1
file.close()

# %%
def distance_(cust_1, cust_2):
    return (((cust_1["XCOORD"] - cust_2["XCOORD"])**2 + (cust_1["YCOORD"] - cust_2["YCOORD"])**2)**(1/2))

# %%
class Truck:
    def __init__(self):
        self.route = []
        self.go_from = 0
        self.go_to = 0
        self.load = capacity
        self.timer = 0
    def __eq__(self, other): 
         return self.go_from == other.go_from and self.go_to == other.go_to

# %%
def find_start_desicion(customers, ntruks):
    lenght = 0
    trucks = []
    for i in range(ntruks):
        trucks.append(Truck())
    not_visited = customers.shape[0] - 1
    for truck in trucks:
        truck.go_from = customers.iloc[0]
        truck.route.append(customers.iloc[0])
    while(not_visited > 0):
        cant_find_decision = 0
        for truck in trucks:
            posible_distances = []
            for i in range(1, customers.shape[0]):
                cust_finish_time = customers.iloc[i]["DUE DATE"]
                if ((customers.iloc[i]["VISITED"] == False) & (cust_finish_time > truck.timer) & (truck.load >= customers.iloc[i]["DEMAND"])):
                    dist = distance_(truck.go_from, customers.iloc[i])
                    posible_distances.append((dist, i))
            if (len(posible_distances) > 0):
                closest_cust = min(posible_distances, key=lambda x:x[0])
                if (truck.timer < customers.iloc[closest_cust[1]]["DUE DATE"]):
                    truck.go_to = customers.iloc[closest_cust[1]]
                    lenght += closest_cust[0] + truck.go_to["SERVICE TIME"]
                    truck.timer += closest_cust[0] + (truck.go_to["READY TIME"] - truck.timer if (truck.go_to["READY TIME"] > truck.timer) else 0) + truck.go_to["SERVICE TIME"]
                    truck.load -= truck.go_to["DEMAND"]
                    print(not_visited)
                    customers.iloc[closest_cust[1]]["VISITED"] = True
                    truck.route.append(truck.go_to)
                    truck.go_from = truck.go_to
                    not_visited -= 1
                    if (not_visited == 0):
                        break
            else:
                cant_find_decision += 1
                print("ERROR: ",cant_find_decision)
        if (cant_find_decision == ntrucks):
            return 0, 0
    
    routes = []
    for truck in trucks:
        truck.route.append(customers.iloc[0])
        routes.append(truck.route)
    return routes, lenght

# %%
def find_min_lories(customers):
    sum_demands = 0
    for index, customer in customers.iterrows():
        sum_demands += customer["DEMAND"]
    num_lories = int(sum_demands / capacity) + 1
    return num_lories

# %%
to_change_cust = customers.copy()
ntrucks = find_min_lories(customers)
ntrucks = int(customers.shape[0] / 2)

            x_1 = route[0]["XCOORD"]
            y_1 = route[0]["YCOORD"]
            x_2 = route[1]["XCOORD"]
            y_2 = route[1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
        return fig1

# %%
def plot_routes(routes):
    ntruck = 0

    for truck in routes:
        print("TRUCK NUMBER = ", ntruck)
        counter = 0
        fig1, ax1 = plt.subplots()
        for i in range(len(truck) - 1):
            x_1 = truck[i]["XCOORD"]
            y_1 = truck[i]["YCOORD"]
            x_2 = truck[i + 1]["XCOORD"]
            y_2 = truck[i + 1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
            counter += 1
    #     fig1.savefig(str(ntruck) +".png")
        ntruck += 1

# %%
def plot_routes_all(routes):
    ntruck = 0
    fig1, ax1 = plt.subplots()
    for truck in routes:
        print("TRUCK NUMBER = ", ntruck)
        counter = 0
        
        for i in range(len(truck) - 1):
            x_1 = truck[i]["XCOORD"]
            y_1 = truck[i]["YCOORD"]
            x_2 = truck[i + 1]["XCOORD"]
            y_2 = truck[i + 1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
            counter += 1
    #     fig1.savefig(str(ntruck) +".png")
        ntruck += 1

# %%
def total_distance(routes___):
    tot_distance = 0
    for i_1 in range(len(routes___)):
        for j_1 in range(len(routes___[i_1]) - 1):
            tot_distance += distance_(routes___[i_1][j_1], routes___[i_1][j_1 + 1])
    return tot_distance

# %%
def count_route_dist(route):
    dist = 0
    for i_3 in range(len(route) - 1):
        dist += distance_(route[i_3], route[i_3 - 1])
    return dist

# %%
def aprove_solution(routes):
    ncusts_must = customers.shape[0]
    ncusts_now = 0
    for route in routes:
        timer = 0
        load = capacity
        for ind in range(len(route) - 1):
            if ((route[ind]["DUE DATE"] < timer) | (load < 0)):
                return False
            else:
                timer += distance_(route[ind], route[ind + 1]) + route[ind + 1]["SERVICE TIME"] + (timer - route[ind + 1]["READY TIME"] if (route[ind + 1]["READY TIME"] > timer) else 0)
                load -= route[ind]["DEMAND"]
                ncusts_now += 1
    ncusts_now -= len(routes)
    print(ncusts_must, ncusts_now)
    return True

# %%
def aprove_route_solution(route_):
    timer = 0
    for ind in range(len(route_) - 1):
        if ((route_[ind]["DUE DATE"] < timer)):
            return False
        else:
            timer += distance_(route_[ind], route_[ind + 1]) + route_[ind + 1]["SERVICE TIME"] + (timer - route_[ind + 1]["READY TIME"] if (route_[ind + 1]["READY TIME"] > timer) else 0)
    return True

# %%
def to_best_place(pt, route, rts_, rts_dist, ind):
    load = capacity
    for cust in route:
        load -= cust["DEMAND"]
    load -= pt["DEMAND"]
    if (load < 0):
        print("Not anought of load")
        return route, False
    t_route = route.copy()
    
    for cust_ind in range(1, len(route)):
        t_route.insert(cust_ind, pt)
        if (aprove_route_solution(t_route) == True):
            rts_tmp = copy.deepcopy(rts_)
            rts_tmp[ind] = t_route
            tmp_dist = total_distance(rts_tmp)
#             print(total_distance(rts_), tmp_dist, rts_dist)
            if (tmp_dist < rts_dist):
                return t_route, True
        t_route = route.copy()
    return route, False

# %%
import random
def local_search(_routes_):
    range_i = [random.randrange(1, len(_routes_), 1) for i in range(int(len(_routes_)/3))]
    print(range_i)
    range_k = [random.randrange(1, len(_routes_), 1) for i in range(int(len(_routes_)/3))]
    print(range_k)
    for i in range_i:
        for k in range_k:
            if (i == k):
                continue
            for j in range(1, len(_routes_[i]) - 1):
                from_delete_tmp = _routes_[i].copy()
                from_delete = _routes_[i].copy()
                pt_ = from_delete[j].copy()
                abs_dist = total_distance(_routes_)
                del(from_delete[j])

                to_insert = _routes_[k].copy()
                tmp_rts_ = copy.deepcopy(_routes_)
                tmp_rts_[i] = from_delete
                to_insert, is_changed = to_best_place(pt_, to_insert, tmp_rts_, abs_dist, k)
                if (is_changed == True):
                    tmp_rts_[k] = to_insert
                    _routes_ = copy.deepcopy(tmp_rts_)
                    break
                else:
                    _routes_[i] = from_delete_tmp
    return _routes_

# %%
def two_opt_swap(route):
    route_dist = count_route_dist(route)
    for i in range(1,len(route) - 1):
        route_tmp = route[0: i]
        route_tmp.extend([route[z] for z in range(len(route) - i - 1, i - 1, -1)])
        route_tmp.extend(route[len(route) - i: len(route)])
        if (count_route_dist(route_tmp) < count_route_dist(route)):
            return route_tmp
    return route

# %%
def perturb(routes):
    for _i_ in range(len(routes)):
        res = two_opt_swap(routes[_i_])
        if (count_route_dist(res) < count_route_dist(routes[_i_])):
#             for asdasdaksd in routes[_i_]:
#                 print(asdasdaksd["CUST NO"])
#             for asdasdaksd in res:
#                 print(asdasdaksd["CUST NO"])
            routes[_i_] = res
    return routes

# %%
def ILS(___routes___):
    for najksdi in range(30):
        print("Before: ",total_distance( ___routes___))
        ___routes___ = local_search(___routes___)
        go_next = True
        while(go_next):
            for asdasd in range(len(___routes___)):
                if (len(___routes___[asdasd]) <= 2):
                    del(___routes___[asdasd])
                    go_next = True
                    break
                else:
                    go_next = False
        ___routes___ = perturb(___routes___)
        print("After: ",total_distance(___routes___))
    return ___routes___

# %%
rs = ILS(copy.deepcopy(clear_routes))
# Out:
# Before:  95647.76570971972
# [22, 80, 76, 279, 280, 212, 182, 203, 143, 287, 192, 235, 77, 219, 141, 244, 53, 279, 294, 286, 268, 172, 206, 271, 3, 106, 154, 69, 153, 221, 267, 79, 213, 84, 143, 284, 146, 23, 44, 201, 197, 217, 173, 245, 228, 251, 271, 98, 104, 169, 112, 278, 82, 67, 109, 289, 66, 181, 77, 60, 232, 156, 59, 15, 22, 212, 145, 94, 200, 297, 25, 282, 205, 13, 27, 113, 149, 214, 216, 197, 149, 120, 143, 143, 32, 92, 281, 245, 117, 147, 131, 96, 258, 148, 104, 91, 293, 254, 223, 79]
# [275, 265, 57, 85, 137, 193, 130, 66, 75, 79, 141, 174, 229, 56, 29, 20, 274, 87, 71, 50, 101, 115, 38, 292, 133, 296, 86, 226, 262, 287, 237, 5, 44, 235, 208, 246, 135, 68, 28, 205, 214, 185, 243, 118, 220, 101, 239, 184, 73, 285, 92, 152, 210, 189, 93, 159, 100, 233, 299, 228, 219, 108, 295, 56, 162, 289, 256, 53, 84, 83, 97, 69, 100, 249, 294, 240, 95, 251, 213, 54, 144, 288, 217, 94, 64, 1, 201, 49, 212, 30, 203, 247, 115, 251, 75, 26, 39, 166, 228, 289]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load

# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  43991.63391881148
# Before:  43991.63391881148
# [38, 33, 39, 31, 17, 8, 5, 38, 30, 46, 12, 34, 3, 18, 46, 41]
# [13, 8, 9, 17, 23, 26, 12, 36, 24, 21, 13, 26, 9, 11, 46, 46]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  39815.62049866155
# Before:  39815.62049866155
# [37, 19, 9, 28, 11, 35, 19, 6, 16, 20, 15, 19, 30]
# [20, 11, 18, 2, 10, 25, 18, 31, 38, 19, 3, 34, 24]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  36798.34455095581
# Before:  36798.34455095581
# [4, 20, 3, 28, 2, 15, 9, 30, 9, 10, 2]
# [29, 10, 2, 32, 2, 2, 4, 32, 5, 11, 7]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  35677.54723022493
# Before:  35677.54723022493
# [10, 3, 25, 12, 27, 10, 28, 9, 19, 26, 19]
# [14, 33, 17, 2, 3, 17, 8, 3, 7, 25, 6]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5078         try:
# -> 5079             object.__getattribute__(self, name)
#    5080             return object.__setattr__(self, name, value)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in name(self)
#     396         """
# --> 397         return self._name
#     398
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5062                 name in self._accessors):
# -> 5063             return object.__getattribute__(self, name)
#    5064         else:
#
# AttributeError: 'Series' object has no attribute '_name'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-75dd7331b593> in <module>
# ----> 1 rs = ILS(copy.deepcopy(clear_routes))
#
# <ipython-input-22-dfc018bd10df> in ILS(___routes___)
#       2     for najksdi in range(30):
#       3         print("Before: ",total_distance( ___routes___))
# ----> 4         ___routes___ = local_search(___routes___)
#       5         go_next = True
#       6         while(go_next):
#
# <ipython-input-19-f67780a45bf9> in local_search(_routes_)
#      19                 tmp_rts_ = copy.deepcopy(_routes_)
#      20                 tmp_rts_[i] = from_delete
# ---> 21                 to_insert, is_changed = to_best_place(pt_, to_insert, tmp_rts_, abs_dist, k)
#      22                 if (is_changed == True):
#      23                     tmp_rts_[k] = to_insert
#
# <ipython-input-18-0c1f63b66642> in to_best_place(pt, route, rts_, rts_dist, ind)
#      12         t_route.insert(cust_ind, pt)
#      13         if (aprove_route_solution(t_route) == True):
# ---> 14             rts_tmp = copy.deepcopy(rts_)
#      15             rts_tmp[ind] = t_route
#      16             tmp_dist = total_distance(rts_tmp)
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     148     copier = _deepcopy_dispatch.get(cls)
#     149     if copier:
# --> 150         y = copier(x, memo)
#     151     else:
#     152         try:
#
# /usr/lib/python3.6/copy.py in _deepcopy_list(x, memo, deepcopy)
#     213     append = y.append
#     214     for a in x:
# --> 215         append(deepcopy(a, memo))
#     216     return y
#     217 d[list] = _deepcopy_list
#
# /usr/lib/python3.6/copy.py in deepcopy(x, memo, _nil)
#     159             copier = getattr(x, "__deepcopy__", None)
#     160             if copier:
# --> 161                 y = copier(memo)
#     162             else:
#     163                 reductor = dispatch_table.get(cls)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __deepcopy__(self, memo)
#    5817         if memo is None:
#    5818             memo = {}
# -> 5819         return self.copy(deep=True)
#    5820
#    5821     def _convert(self, datetime=False, numeric=False, timedelta=False,
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in copy(self, deep)
#    5803         """
#    5804         data = self._data.copy(deep=deep)
# -> 5805         return self._constructor(data).__finalize__(self)
#    5806
#    5807     def __copy__(self, deep=True):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     266         generic.NDFrame.__init__(self, data, fastpath=True)
#     267
# --> 268         self.name = name
#     269         self._set_axis(0, index, fastpath=True)
#     270
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5077
#    5078         try:
# -> 5079             object.__getattribute__(self, name)
#    5080             return object.__setattr__(self, name, value)
#    5081         except AttributeError:
#
# KeyboardInterrupt:

# %%
rs = ILS(copy.deepcopy(rs))

# %%
print(total_distance(rs))

# %%
for rt in rs:
    print("NEW ROUTE")
    for ct in rt:
        print(ct["CUST NO"])

# %%
plot_routes(rs)

# %%
plot_routes_all(rs)
