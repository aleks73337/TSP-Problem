# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output

txt_path = "instances/C203.txt"
file = open(txt_path, 'r')
import re
number = 0
capacity = 0
counter = 0
customers = pd.DataFrame(columns = ['CUST NO', 'XCOORD', 'YCOORD', 'DEMAND', 'READY TIME', 'DUE DATE', 'SERVICE TIME', 'VISITED'])
for line in file:
    if (counter == 4):
        values = re.findall("\s*\d*\s*", line)
        number = int(values[0].replace(" ", ""))
        capacity = int(values[1].replace(" ", ""))
    if (counter > 8):
        values = re.findall("\s*\d*\s*", line)
        customers = customers.append({'CUST NO' : int(values[0].replace(" ", "")), 
                          'XCOORD' : int(values[1].replace(" ", "")), 
                          'YCOORD' : int(values[2].replace(" ", "")), 
                          'DEMAND' : int(values[3].replace(" ", "")), 
                          'READY TIME' : int(values[4].replace(" ", "")), 
                          'DUE DATE' : int(values[5].replace(" ", "")), 
                          'SERVICE TIME' : int(values[6].replace(" ", "")),
                          'VISITED': False}, ignore_index=True)
    counter = counter + 1
file.close()

# %%
def distance_(cust_1, cust_2):
    return (((cust_1["XCOORD"] - cust_2["XCOORD"])**2 + (cust_1["YCOORD"] - cust_2["YCOORD"])**2)**(1/2))

# %%
class Truck:
    def __init__(self):
        self.route = []
        self.go_from = 0
        self.go_to = 0
        self.load = capacity
        self.timer = 0
    def __eq__(self, other): 
         return self.go_from == other.go_from and self.go_to == other.go_to

# %%
def find_start_desicion(customers, ntruks):
    lenght = 0
    trucks = []
    for i in range(ntruks):
        trucks.append(Truck())
    not_visited = customers.shape[0] - 1
    for truck in trucks:
        truck.go_from = customers.iloc[0]
        truck.route.append(customers.iloc[0])
    while(not_visited > 0):
        cant_find_decision = 0
        for truck in trucks:
            posible_distances = []
            for i in range(1, customers.shape[0]):
                cust_finish_time = customers.iloc[i]["DUE DATE"]
                if ((customers.iloc[i]["VISITED"] == False) & (cust_finish_time > truck.timer) & (truck.load >= customers.iloc[i]["DEMAND"])):
                    dist = distance_(truck.go_from, customers.iloc[i])
                    posible_distances.append((dist, i))
            if (len(posible_distances) > 0):
                closest_cust = min(posible_distances, key=lambda x:x[0])
                if (truck.timer < customers.iloc[closest_cust[1]]["DUE DATE"]):
                    truck.go_to = customers.iloc[closest_cust[1]]
                    lenght += closest_cust[0] + truck.go_to["SERVICE TIME"]
                    truck.timer += closest_cust[0] + (truck.go_to["READY TIME"] - truck.timer if (truck.go_to["READY TIME"] > truck.timer) else 0) + truck.go_to["SERVICE TIME"]
                    truck.load -= truck.go_to["DEMAND"]
                    print(not_visited)
                    customers.iloc[closest_cust[1]]["VISITED"] = True
                    truck.route.append(truck.go_to)
                    truck.go_from = truck.go_to
                    not_visited -= 1
                    if (not_visited == 0):
                        break
            else:
                cant_find_decision += 1
                print("ERROR: ",cant_find_decision)
        if (cant_find_decision == ntrucks):
            return 0, 0
    
    routes = []
    for truck in trucks:
        truck.route.append(customers.iloc[0])
        routes.append(truck.route)
    return routes, lenght

# %%
def find_min_lories(customers):
    sum_demands = 0
    for index, customer in customers.iterrows():
        sum_demands += customer["DEMAND"]
    num_lories = int(sum_demands / capacity) + 1
    return num_lories

# %%
to_change_cust = customers.copy()
ntrucks = find_min_lories(customers)
ntrucks = 20

print(ntrucks) ## 43 для 600 кастомеров

routes, lenght = find_start_desicion(to_change_cust, ntrucks)
while(lenght == 0):
    clear_output()
    print(ntrucks, " failed")
    to_change_cust = customers.copy()
    routes, lenght = find_start_desicion(to_change_cust, ntrucks)
    ntrucks += 1
print(lenght)
# Out:
# 20
# 100
# 99
# 98
# 97
# 96
# 95
# 94
# 93
# 92
# 91
# 90
# 89
# 88
# 87
# 86
# 85
# 84
# 83
# 82
# 81
# 80
# 79
# 78
# 77
# 76
# 75
# 74
# 73
# 72
# 71
# 70
# 69
# 68
# 67
# 66
# 65
# 64
# 63
# 62
# 61
# 60
# 59
# 58
# 57
# 56
# 55
# 54
# 53
# 52
# 51
# 50
# 49
# 48
# 47
# 46
# 45
# 44
# 43
# 42
# 41
# 40
# 39
# 38
# 37
# 36
# 35
# 34
# 33
# 32
# 31
# 30
# 29
# 28
# 27
# 26
# 25
# 24
# 23
# 22
# 21
# 20
# 19
# 18
# ERROR:  1
# 17
# 16
# 15
# 14
# 13
# 12
# 11
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# ERROR:  2
# ERROR:  3
# 3
# ERROR:  1
# ERROR:  2
# ERROR:  3
# 2
# ERROR:  4
# ERROR:  5
# ERROR:  6
# ERROR:  7
# ERROR:  8
# ERROR:  9
# 1
# 11032.385397810043

# %%
import copy

# %%
clear_routes = copy.deepcopy(routes)

# %%
def plot_way(truck):
        fig1, ax1 = plt.subplots()
        for route in truck:
            x_1 = route[0]["XCOORD"]
            y_1 = route[0]["YCOORD"]
            x_2 = route[1]["XCOORD"]
            y_2 = route[1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
        return fig1

# %%
def plot_routes(routes):
    ntruck = 0

    for truck in routes:
        print("TRUCK NUMBER = ", ntruck)
        counter = 0
        fig1, ax1 = plt.subplots()
        for i in range(len(truck) - 1):
            x_1 = truck[i]["XCOORD"]
            y_1 = truck[i]["YCOORD"]
            x_2 = truck[i + 1]["XCOORD"]
            y_2 = truck[i + 1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
            counter += 1
    #     fig1.savefig(str(ntruck) +".png")
        ntruck += 1

# %%
def total_distance(routes___):
    tot_distance = 0
    for i_1 in range(len(routes___)):
        for j_1 in range(len(routes___[i_1]) - 1):
            tot_distance += distance_(routes___[i_1][j_1], routes___[i_1][j_1 + 1])
    return tot_distance

# %%
def count_route_dist(route):
    dist = 0
    for i_3 in range(len(route) - 1):
        dist += distance_(route[i_3], route[i_3 - 1])
    return dist

# %%
def aprove_solution(routes):
    ncusts_must = customers.shape[0]
    ncusts_now = 0
    for route in routes:
        timer = 0
        load = capacity
        for ind in range(len(route) - 1):
            if ((route[ind]["DUE DATE"] < timer) | (load < 0)):
                return False
            else:
                timer += distance_(route[ind], route[ind + 1]) + route[ind + 1]["SERVICE TIME"] + (timer - route[ind + 1]["READY TIME"] if (route[ind + 1]["READY TIME"] > timer) else 0)
                load -= route[ind]["DEMAND"]
                ncusts_now += 1
    ncusts_now -= len(routes)
    print(ncusts_must, ncusts_now)
    return True

# %%
def aprove_route_solution(route_):
    timer = 0
    for ind in range(len(route_) - 1):
        if ((route_[ind]["DUE DATE"] < timer)):
            return False
        else:
            timer += distance_(route_[ind], route_[ind + 1]) + route_[ind + 1]["SERVICE TIME"] + (timer - route_[ind + 1]["READY TIME"] if (route_[ind + 1]["READY TIME"] > timer) else 0)
    return True

# %%
def to_best_place(pt, route, rts_, rts_dist, ind):
    load = capacity
    for cust in route:
        load -= cust["DEMAND"]
    load -= pt["DEMAND"]
    if (load < 0):
        print("Not anought of load")
        return route, False
    t_route = route.copy()
    for cust_ind in range(1, len(route)):
        t_route.insert(cust_ind, pt)
        if (aprove_route_solution(t_route) == True):
            rts_tmp = copy.deepcopy(rts_)
            rts_tmp[ind] = t_route
            if (total_distance(rts_tmp) < rts_dist):
                print("Я нашел!")
                return t_route, True
        t_route = route.copy()
    return route, False

# %%
def local_search(_routes_):
    
    for i in range(len(_routes_)):
        for k in range(len(_routes_)):
            for j in range(1, len(_routes_[i]) - 1):
                from_delete_tmp = _routes_[i].copy()
                from_delete = _routes_[i].copy()
                pt_ = from_delete[j].copy()
                abs_dist = total_distance(_routes_)
                print(abs_dist)
                del(from_delete[j])

                to_insert = _routes_[k].copy()
                tmp_rts_ = copy.deepcopy(_routes_)
                tmp_rts_[i] = from_delete_tmp
                to_insert, is_changed = to_best_place(pt_, to_insert, _routes_, abs_dist, k)
                if (is_changed == True):
                    tmp_rts_[k] = to_insert
                    print(total_distance(tmp_rts_))
                    return tmp_rts
                else:
                    _routes_[i] = from_delete_tmp
    return _routes_

# %%
rs = local_search(copy.deepcopy(clear_routes))
# Out:
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# 2847.4297052844026
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-9d62e1635b95> in <module>
# ----> 1 rs = local_search(copy.deepcopy(clear_routes))
#
# <ipython-input-77-ae8b4b37733b> in local_search(_routes_)
#      14                 tmp_rts_ = copy.deepcopy(_routes_)
#      15                 tmp_rts_[i] = from_delete_tmp
# ---> 16                 to_insert, is_changed = to_best_place(pt_, to_insert, _routes_, abs_dist, k)
#      17                 if (is_changed == True):
#      18                     tmp_rts_[k] = to_insert
#
# <ipython-input-74-da574e467629> in to_best_place(pt, route, rts_, rts_dist, ind)
#      13             rts_tmp = copy.deepcopy(rts_)
#      14             rts_tmp[ind] = t_route
# ---> 15             if (total_distance(rts_tmp) < rts_dist):
#      16                 print("Я нашел!")
#      17                 return t_route, True
#
# <ipython-input-63-474db74536f3> in total_distance(routes___)
#       3     for i_1 in range(len(routes___)):
#       4         for j_1 in range(len(routes___[i_1]) - 1):
# ----> 5             tot_distance += distance_(routes___[i_1][j_1], routes___[i_1][j_1 + 1])
#       6     return tot_distance
#
# <ipython-input-2-4cee1d62ffcb> in distance_(cust_1, cust_2)
#       1 def distance_(cust_1, cust_2):
# ----> 2     return (((cust_1["XCOORD"] - cust_2["XCOORD"])**2 + (cust_1["YCOORD"] - cust_2["YCOORD"])**2)**(1/2))
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4349         # use this, e.g. DatetimeIndex
#    4350         # Things like `Series._get_value` (via .at) pass the EA directly here.
# -> 4351         s = getattr(series, '_values', series)
#    4352         if isinstance(s, (ExtensionArray, Index)) and is_scalar(key):
#    4353             # GH 20882, 21257
#
# KeyboardInterrupt:

# %%
print(aprove_solution(clear_routes))
# Out:
# 101 100
# True

# %%
plot_routes(rs)
# Out:
# TRUCK NUMBER =  0
# TRUCK NUMBER =  1
# TRUCK NUMBER =  2
# TRUCK NUMBER =  3
# TRUCK NUMBER =  4
# TRUCK NUMBER =  5
# TRUCK NUMBER =  6
# TRUCK NUMBER =  7
# TRUCK NUMBER =  8
# TRUCK NUMBER =  9
# TRUCK NUMBER =  10
# TRUCK NUMBER =  11
# TRUCK NUMBER =  12
# TRUCK NUMBER =  13
# TRUCK NUMBER =  14
# TRUCK NUMBER =  15
# TRUCK NUMBER =  16
# TRUCK NUMBER =  17
# TRUCK NUMBER =  18
# TRUCK NUMBER =  19

# %%
print(total_distance(routes))
# Out:
# 2535.111244501338

# %%
rs = improve_routes(copy.deepcopy(clear_routes))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-94-daff7b17ced7> in <module>
# ----> 1 rs = improve_routes(copy.deepcopy(clear_routes))
#
# <ipython-input-92-222857e388fa> in improve_routes(_routes)
#       5         for to_rt in range(len(best_routes_)):
#       6             for pt_in_from in best_routes_[from_rt]:
# ----> 7                 best_routes_[to_rt] = to_best_place(pt_in_from, best_routes_[to_rt], copy.deepcopy(best_routes_), to_rt)
#       8     return best_routes_
#       9                 #если с новой точкой общий скор меньше, то оставляем
#
# <ipython-input-91-62b12e7cb46d> in to_best_place(pt, route, rts_, ind)
#       7         return route
#       8     t_route = route.copy()
# ----> 9     rts_dist = total_distance(rts_)
#      10     for cust_ind in range(1, len(route) - 1):
#      11         t_route.insert(cust_ind, pt)
#
# <ipython-input-74-474db74536f3> in total_distance(routes___)
#       3     for i_1 in range(len(routes___)):
#       4         for j_1 in range(len(routes___[i_1]) - 1):
# ----> 5             tot_distance += distance_(routes___[i_1][j_1], routes___[i_1][j_1 + 1])
#       6     return tot_distance
#
# <ipython-input-51-4cee1d62ffcb> in distance_(cust_1, cust_2)
#       1 def distance_(cust_1, cust_2):
# ----> 2     return (((cust_1["XCOORD"] - cust_2["XCOORD"])**2 + (cust_1["YCOORD"] - cust_2["YCOORD"])**2)**(1/2))
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4367                     return s[key]
#    4368
# -> 4369         s = com.values_from_object(series)
#    4370         k = com.values_from_object(key)
#    4371
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in get_values(self)
#     492         Same as values (but handles sparseness conversions); is a view.
#     493         """
# --> 494         return self._data.get_values()
#     495
#     496     @property
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in get_values(self)
#    1556     def get_values(self):
#    1557         """ return a dense type view """
# -> 1558         return np.array(self._block.to_dense(), copy=False)
#    1559
#    1560     @property
#
# KeyboardInterrupt:
