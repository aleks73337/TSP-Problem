# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output

txt_path = "instances/RC105.txt"
file = open(txt_path, 'r')
import re
number = 0
capacity = 0
counter = 0
customers = pd.DataFrame(columns = ['CUST NO', 'XCOORD', 'YCOORD', 'DEMAND', 'READY TIME', 'DUE DATE', 'SERVICE TIME', 'VISITED'])
for line in file:
    if (counter == 4):
        values = re.findall("\s*\d*\s*", line)
        number = int(values[0].replace(" ", ""))
        capacity = int(values[1].replace(" ", ""))
    if (counter > 8):
        values = re.findall("\s*\d*\s*", line)
        customers = customers.append({'CUST NO' : int(values[0].replace(" ", "")), 
                          'XCOORD' : int(values[1].replace(" ", "")), 
                          'YCOORD' : int(values[2].replace(" ", "")), 
                          'DEMAND' : int(values[3].replace(" ", "")), 
                          'READY TIME' : int(values[4].replace(" ", "")), 
                          'DUE DATE' : int(values[5].replace(" ", "")), 
                          'SERVICE TIME' : int(values[6].replace(" ", "")),
                          'VISITED': False}, ignore_index=True)
    counter = counter + 1
file.close()

# %%
def distance_(cust_1, cust_2):
    return (((cust_1["XCOORD"] - cust_2["XCOORD"])**2 + (cust_1["YCOORD"] - cust_2["YCOORD"])**2)**(1/2))

# %%
class Truck:
    def __init__(self):
        self.route = []
        self.go_from = 0
        self.go_to = 0
        self.load = capacity
        self.timer = 0
    def __eq__(self, other): 
         return self.go_from == other.go_from and self.go_to == other.go_to

# %%
def find_start_desicion(customers, ntruks):
    lenght = 0
    trucks = []
    for i in range(ntruks):
        trucks.append(Truck())
    not_visited = customers.shape[0] - 1
    for truck in trucks:
        truck.go_from = customers.iloc[0]
        truck.route.append(customers.iloc[0])
    while(not_visited > 0):
        cant_find_decision = 0
        for truck in trucks:
            posible_distances = []
            for i in range(1, customers.shape[0]):
                cust_finish_time = customers.iloc[i]["DUE DATE"]
                if ((customers.iloc[i]["VISITED"] == False) & (cust_finish_time > truck.timer) & (truck.load >= customers.iloc[i]["DEMAND"])):
                    dist = distance_(truck.go_from, customers.iloc[i])
                    posible_distances.append((dist, i))
            if (len(posible_distances) > 0):
                closest_cust = min(posible_distances, key=lambda x:x[0])
                if (truck.timer < customers.iloc[closest_cust[1]]["DUE DATE"]):
                    truck.go_to = customers.iloc[closest_cust[1]]
                    lenght += closest_cust[0] + truck.go_to["SERVICE TIME"]
                    truck.timer += closest_cust[0] + (truck.go_to["READY TIME"] - truck.timer if (truck.go_to["READY TIME"] > truck.timer) else 0) + truck.go_to["SERVICE TIME"]
                    truck.load -= truck.go_to["DEMAND"]
                    print(not_visited)
                    customers.iloc[closest_cust[1]]["VISITED"] = True
                    truck.route.append(truck.go_to)
                    truck.go_from = truck.go_to
                    not_visited -= 1
                    if (not_visited == 0):
                        break
            else:
                cant_find_decision += 1
                print("ERROR: ",cant_find_decision)
        if (cant_find_decision == ntrucks):
            return 0, 0
    
    routes = []
    for truck in trucks:
        truck.route.append(customers.iloc[0])
        routes.append(truck.route)
    return routes, lenght

# %%
def find_min_lories(customers):
    sum_demands = 0
    for index, customer in customers.iterrows():
        sum_demands += customer["DEMAND"]
    num_lories = int(sum_demands / capacity) + 1
    return num_lories

# %%
to_change_cust = customers.copy()
ntrucks = find_min_lories(customers)

print(ntrucks) ## 43 для 600 кастомеров

routes, lenght = find_start_desicion(to_change_cust, ntrucks)
while(lenght == 0):
    clear_output()
    print(ntrucks, " failed")
    to_change_cust = customers.copy()
    routes, lenght = find_start_desicion(to_change_cust, ntrucks)
    ntrucks += 1
print(lenght)
# Out:
# 58  failed
# 100
# 99
# 98
# 97
# 96
# 95
# 94
# 93
# 92
# 91
# 90
# 89
# 88
# 87
# 86
# 85
# 84
# 83
# 82
# 81
# 80
# 79
# 78
# 77
# 76
# 75
# 74
# 73
# 72
# 71
# 70
# 69
# 68
# 67
# 66
# 65
# 64
# 63
# 62
# 61
# 60
# 59
# 58
# 57
# 56
# 55
# 54
# 53
# 52
# 51
# 50
# 49
# 48
# 47
# 46
# 45
# 44
# 43
# 42
# ERROR:  1
# 41
# 40
# 39
# 38
# 37
# 36
# 35
# 34
# 33
# 32
# 31
# 30
# 29
# 28
# 27
# 26
# 25
# ERROR:  2
# ERROR:  3
# 24
# 23
# 22
# 21
# ERROR:  4
# 20
# 19
# 18
# 17
# 16
# 15
# 14
# 13
# 12
# 11
# 10
# 9
# 8
# 7
# ERROR:  5
# 6
# ERROR:  6
# 5
# 4
# ERROR:  7
# ERROR:  8
# ERROR:  9
# 3
# ERROR:  10
# 2
# 1
# 3758.7750425747395

# %%
import copy

# %%
clear_routes = copy.deepcopy(routes)

# %%
def plot_way(truck):
        fig1, ax1 = plt.subplots()
        for route in truck:
            x_1 = route[0]["XCOORD"]
            y_1 = route[0]["YCOORD"]
            x_2 = route[1]["XCOORD"]
            y_2 = route[1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
        return fig1

# %%
def plot_routes(routes):
    ntruck = 0

    for truck in routes:
        print("TRUCK NUMBER = ", ntruck)
        counter = 0
        fig1, ax1 = plt.subplots()
        for i in range(len(truck) - 1):
            x_1 = truck[i]["XCOORD"]
            y_1 = truck[i]["YCOORD"]
            x_2 = truck[i + 1]["XCOORD"]
            y_2 = truck[i + 1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
            counter += 1
    #     fig1.savefig(str(ntruck) +".png")
        ntruck += 1

# %%
def plot_routes_all(routes):
    ntruck = 0
    fig1, ax1 = plt.subplots()
    for truck in routes:
        print("TRUCK NUMBER = ", ntruck)
        counter = 0
        
        for i in range(len(truck) - 1):
            x_1 = truck[i]["XCOORD"]
            y_1 = truck[i]["YCOORD"]
            x_2 = truck[i + 1]["XCOORD"]
            y_2 = truck[i + 1]["YCOORD"]
            ax1.plot(x_1, y_1, ".")
            ax1.plot(x_2, y_2, '.')
            ax1.plot((x_1, x_2), (y_1, y_2), color = 'black')
            counter += 1
    #     fig1.savefig(str(ntruck) +".png")
        ntruck += 1

# %%
def total_distance(routes___):
    tot_distance = 0
    for i_1 in range(len(routes___)):
        for j_1 in range(len(routes___[i_1]) - 1):
            tot_distance += distance_(routes___[i_1][j_1], routes___[i_1][j_1 + 1])
    return tot_distance

# %%
def count_route_dist(route):
    dist = 0
    for i_3 in range(len(route) - 1):
        dist += distance_(route[i_3], route[i_3 - 1])
    return dist

# %%
def aprove_solution(routes):
    ncusts_must = customers.shape[0]
    ncusts_now = 0
    for route in routes:
        timer = 0
        load = capacity
        for ind in range(len(route) - 1):
            if ((route[ind]["DUE DATE"] < timer) | (load < 0)):
                return False
            else:
                timer += distance_(route[ind], route[ind + 1]) + route[ind + 1]["SERVICE TIME"] + (timer - route[ind + 1]["READY TIME"] if (route[ind + 1]["READY TIME"] > timer) else 0)
                load -= route[ind]["DEMAND"]
                ncusts_now += 1
    ncusts_now -= len(routes)
    print(ncusts_must, ncusts_now)
    return True

# %%
def aprove_route_solution(route_):
    timer = 0
    for ind in range(len(route_) - 1):
        if ((route_[ind]["DUE DATE"] < timer)):
            return False
        else:
            timer += distance_(route_[ind], route_[ind + 1]) + route_[ind + 1]["SERVICE TIME"] + (timer - route_[ind + 1]["READY TIME"] if (route_[ind + 1]["READY TIME"] > timer) else 0)
    return True

# %%
def to_best_place(pt, route, rts_, rts_dist, ind):
    load = capacity
    for cust in route:
        load -= cust["DEMAND"]
    load -= pt["DEMAND"]
    if (load < 0):
        print("Not anought of load")
        return route, False
    t_route = route.copy()
    
    for cust_ind in range(1, len(route)):
        t_route.insert(cust_ind, pt)
        if (aprove_route_solution(t_route) == True):
            rts_tmp = copy.deepcopy(rts_)
            rts_tmp[ind] = t_route
            tmp_dist = total_distance(rts_tmp)
#             print(total_distance(rts_), tmp_dist, rts_dist)
            if (tmp_dist < rts_dist):
                return t_route, True
        t_route = route.copy()
    return route, False

# %%
import random
def local_search(_routes_):
    range_i = [random.randrange(1, len(_routes_), 1) for i in range(int(len(_routes_)/3))]
    print(range_i)
    range_k = [random.randrange(1, len(_routes_), 1) for i in range(int(len(_routes_)/3))]
    print(range_k)
    for i in range_i:
        for k in range_k:
            if (i == k):
                continue
            for j in range(1, len(_routes_[i]) - 1):
                from_delete_tmp = _routes_[i].copy()
                from_delete = _routes_[i].copy()
                pt_ = from_delete[j].copy()
                abs_dist = total_distance(_routes_)
                del(from_delete[j])

                to_insert = _routes_[k].copy()
                tmp_rts_ = copy.deepcopy(_routes_)
                tmp_rts_[i] = from_delete
                to_insert, is_changed = to_best_place(pt_, to_insert, tmp_rts_, abs_dist, k)
                if (is_changed == True):
                    tmp_rts_[k] = to_insert
                    _routes_ = copy.deepcopy(tmp_rts_)
                    break
                else:
                    _routes_[i] = from_delete_tmp
    return _routes_

# %%
def two_opt_swap(route):
    route_dist = count_route_dist(route)
    for i in range(1,len(route) - 1):
        route_tmp = route[0: i]
        route_tmp.extend([route[z] for z in range(len(route) - i - 1, i - 1, -1)])
        route_tmp.extend(route[len(route) - i: len(route)])
        if (count_route_dist(route_tmp) < count_route_dist(route)):
            return route_tmp
    return route

# %%
def perturb(routes):
    for _i_ in range(len(routes)):
        res = two_opt_swap(routes[_i_])
        if (count_route_dist(res) < count_route_dist(routes[_i_])):
#             for asdasdaksd in routes[_i_]:
#                 print(asdasdaksd["CUST NO"])
#             for asdasdaksd in res:
#                 print(asdasdaksd["CUST NO"])
            routes[_i_] = res
    return routes

# %%
def ILS(___routes___):
    for najksdi in range(30):
        print("Before: ",total_distance( ___routes___))
        ___routes___ = local_search(___routes___)
        go_next = True
        while(go_next):
            for asdasd in range(len(___routes___)):
                if (len(___routes___[asdasd]) <= 2):
                    del(___routes___[asdasd])
                    go_next = True
                    break
                else:
                    go_next = False
        ___routes___ = perturb(___routes___)
        print("After: ",total_distance(___routes___))
    return ___routes___

# %%
rs = ILS(copy.deepcopy(clear_routes))
# Out:
# Before:  5124.266752732949
# [52, 45, 39, 5, 3, 20, 13, 11, 48, 33, 36, 19, 53, 42, 18, 36, 36, 5, 35]
# [9, 42, 7, 5, 21, 41, 46, 24, 3, 13, 31, 38, 33, 51, 51, 17, 51, 45, 39]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  4508.438252695586
# Before:  4508.438252695586
# [38, 19, 2, 5, 22, 24, 18, 6, 10, 31, 30, 25, 18, 4]
# [30, 33, 21, 5, 8, 42, 32, 23, 19, 13, 10, 12, 35, 28]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  3989.1605696991605
# Before:  3989.1605696991605
# [14, 25, 16, 5, 3, 24, 14, 31, 27, 20]
# [14, 3, 13, 24, 30, 21, 6, 19, 16, 31]
# After:  3681.516164036844
# Before:  3681.516164036844
# [14, 19, 14, 11, 24, 9, 10, 14]
# [16, 1, 4, 17, 19, 10, 14, 2]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  3417.8037985181145
# Before:  3417.8037985181145
# [11, 16, 20, 1, 21, 21, 11]
# [21, 20, 5, 1, 6, 5, 17]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  3307.404698532558
# Before:  3307.404698532558
# [5, 7, 8, 17, 12, 15]
# [18, 1, 3, 10, 1, 10]
# After:  3099.4966364718152
# Before:  3099.4966364718152
# [10, 5, 10, 16, 10]
# [16, 12, 5, 9, 15]
# After:  3028.387766202587
# Before:  3028.387766202587
# [10, 9, 3, 5, 10]
# [15, 12, 2, 10, 8]
# Not anought of load
# After:  2897.1040601684695
# Before:  2897.1040601684695
# [13, 4, 9, 8]
# [13, 5, 8, 13]
# Not anought of load
# After:  2792.6769265265516
# Before:  2792.6769265265516
# [2, 6, 12, 13]
# [1, 11, 12, 1]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  2693.9670349233393
# Before:  2693.9670349233393
# [2, 3, 10, 6]
# [11, 12, 11, 10]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  2627.3371192529767
# Before:  2627.3371192529767
# [13, 11, 4, 1]
# [3, 10, 13, 4]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  2496.342170178617
# Before:  2496.342170178617
# [3, 5, 3, 7]
# [7, 10, 9, 12]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# After:  2470.4240543226383
# Before:  2470.4240543226383
# [5, 8, 9, 3]
# [9, 1, 13, 13]
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load
# Not anought of load

# %%
print(total_distance(rs))

# %%
for rt in rs:
    print("NEW ROUTE")
    for ct in rt:
        print(ct["CUST NO"])

# %%
plot_routes(rs)

# %%
plot_routes_all(rs)
